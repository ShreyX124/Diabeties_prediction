# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import sklearn

# %%
df=pd.read_csv("Downloads/diabetes.csv")

# %%
df.head(10) #Displays the first 10 rows of the CSV file
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.columns #Displays the column names
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.info() #Displays info of the CSV file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape #Displays the no of rows X no of columns the mtrix types
# Out:
# (768, 9)

# %%
 df.describe()#Dispayes all the numerial values info
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Calculate corelation matrux
corr_matrix=df.corr()

# Create a Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,cmap="YlGnBu",fmt=".2f",linewidths=.5)
plt.title("Corelation heatmap")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Find the number of null values present in the provided dataset
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Finding the corelation of the outcome with the independent variables
corr_matrix["Outcome"].sort_values(ascending=False)
# Out:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# Name: Outcome, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

X=df.drop("Outcome", axis=1)
X=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Assuming you have already preprocessed the data
df = pd.read_csv("Downloads/diabetes.csv")

# Splitting the dataset into features (X) and target (y)
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# Standardizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
# Setting up Grid Search
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Fit the model
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              verbose=2)

# %%
model = RandomForestClassifier(random_state=42)

# Define the parameter grid to search
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# %%
# Best parameters found by GridSearchCV
best_params = grid_search.best_params_
print("Best parameters:", best_params)

# Predict using the best model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the performance
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# Best parameters: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy: 0.7489177489177489
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81       151
#            1       0.63      0.65      0.64        80
#
#     accuracy                           0.75       231
#    macro avg       0.72      0.73      0.72       231
# weighted avg       0.75      0.75      0.75       231

# %%
# Train the original model (before hyperparameter tuning) on the training set
original_model = RandomForestClassifier(random_state=42)
original_model.fit(X_train, y_train)

# Predict on the test set using the original model
y_pred_original = original_model.predict(X_test)

# %%
# Calculate accuracy for the original model
accuracy_original = accuracy_score(y_test, y_pred_original)

# Generate the classification report for the original model
report_original = classification_report(y_test, y_pred_original)

# Print out the results for the original model
print("Results for the Original Model (before hyperparameter tuning):")
print(f"Accuracy: {accuracy_original}")
print(f"Classification Report:\n{report_original}")
# Out:
# Results for the Original Model (before hyperparameter tuning):
# Accuracy: 0.7575757575757576
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81       151
#            1       0.65      0.66      0.65        80
#
#     accuracy                           0.76       231
#    macro avg       0.73      0.74      0.73       231
# weighted avg       0.76      0.76      0.76       231
